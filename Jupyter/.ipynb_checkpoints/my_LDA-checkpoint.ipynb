# %%
import pandas as pd
import numpy as np


df = pd.read_excel(r'C:\Users\USER\Desktop\web-scraping-\final.xlsx')

# %%
import gensim
from gensim.models.ldamulticore import LdaMulticore
from gensim import corpora, models
import pyLDAvis.gensim_models
from nltk.corpus import stopwords
import string
from nltk.stem.wordnet import WordNetLemmatizer

import warnings
warnings.simplefilter('ignore')
from itertools import chain

# %%
#import nltk
#nltk.download('all')

# %%
df.head()
# Out:
#           topic                                              title  \
# 0      BUSINESS  MAHB faces double whammy of interstate ban, Tu...
# 1      BUSINESS                       RM opens at 4.09 against USD
# 2    COLUMNISTS  Biden needs fresh thinking and more than one term
# 3  SUNDAY VIBES  MONEY THOUGHTS: Ikigai — The uncommon key to c...
# 4      BUSINESS  Labuan FSA appoints new chairman, director gen...
#
#                                              article                   date  \
# 0  KUALA LUMPUR: Affin Hwang Capital expects Mala...  May 4, 2021 @ 10:40am
# 1  KUALA LUMPUR: The ringgit opened easier agains...  May 3, 2021 @ 10:09am
# 2  FORGET about the first 100 days. US President ...  May 3, 2021 @ 12:10am
# 3  HAVE you noticed how life's getting tougher on...   May 2, 2021 @ 8:30am
# 4  KUALA LUMPUR: Labuan Financial Services Author...  Apr 30, 2021 @ 4:15pm
#
#                                                 link
# 0  https://www.nst.com.my/business/2021/05/687692...
# 1  https://www.nst.com.my/business/2021/05/687398...
# 2  https://www.nst.com.my/opinion/columnists/2021...
# 3  https://www.nst.com.my/lifestyle/sunday-vibes/...
# 4  https://www.nst.com.my/business/2021/04/686731...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   topic    107 non-null    object
#  1   title    107 non-null    object
#  2   article  107 non-null    object
#  3   date     107 non-null    object
#  4   link     107 non-null    object
# dtypes: object(5)
# memory usage: 4.3+ KB

# %%
stop = set(stopwords.words('english'))
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()

def clean(text):
    stop_free = ' '.join([word for word in text.lower().split() if word not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = ' '.join([lemma.lemmatize(word) for word in punc_free.split()])
    return normalized.split()

# %%
df['article_clean']=df['article'].apply(clean)

# %%
dictionary = corpora.Dictionary(df['article_clean'])
print(dictionary.num_nnz)
# Out:
# 20580

# %%
doc_term_matrix = [dictionary.doc2bow(doc) for doc in df['article_clean'] ]
print(len(doc_term_matrix))
# Out:
# 107

# %%
lda = gensim.models.ldamodel.LdaModel

# %%
num_topics= 6
# %time ldamodel = lda(doc_term_matrix,num_topics=num_topics,id2word=dictionary,passes=50,minimum_probability=0)
# Out:
# Wall time: 9.6 s

# %%
ldamodel.print_topics(num_topics=num_topics)
# Out:
# [(0,
#   '0.008*"country" + 0.007*"government" + 0.007*"food" + 0.006*"economic" + 0.006*"malaysia" + 0.005*"covid19" + 0.005*"also" + 0.005*"said" + 0.005*"new" + 0.004*"year"'),
#  (1,
#   '0.012*"said" + 0.010*"per" + 0.009*"cent" + 0.008*"malaysia" + 0.007*"bank" + 0.006*"fund" + 0.006*"rating" + 0.005*"investment" + 0.005*"government" + 0.005*"sukuk"'),
#  (2,
#   '0.013*"said" + 0.011*"per" + 0.010*"cent" + 0.008*"market" + 0.007*"year" + 0.006*"2020" + 0.005*"malaysia" + 0.005*"investor" + 0.004*"bank" + 0.004*"policy"'),
#  (3,
#   '0.010*"said" + 0.009*"million" + 0.004*"year" + 0.003*"investor" + 0.003*"yemeni" + 0.003*"per" + 0.003*"real" + 0.003*"virtual" + 0.003*"humanitarian" + 0.003*"market"'),
#  (4,
#   '0.020*"ringgit" + 0.020*"u" + 0.019*"dollar" + 0.015*"currency" + 0.013*"said" + 0.013*"local" + 0.010*"market" + 0.008*"close" + 0.008*"oil" + 0.008*"higher"'),
#  (5,
#   '0.011*"said" + 0.009*"per" + 0.009*"cent" + 0.006*"also" + 0.005*"year" + 0.005*"billion" + 0.005*"investment" + 0.004*"malaysia" + 0.004*"would" + 0.004*"million"')]

# %%
lda_display = pyLDAvis.gensim_models.prepare(ldamodel, doc_term_matrix, dictionary, sort_topics=False, mds='mmds')
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1308823544007012321603716174"></div>
# <script type="text/javascript">
#
# var ldavis_el1308823544007012321603716174_data = {"mdsDat": {"x": [0.05735512942212177, -0.048939827931809246, -0.12670878150546744, -0.10547613496166297, 0.1723778443011739, 0.05139177067564395], "y": [0.16552675117923238, -0.10958424321726859, -0.043040603128434246, 0.1092717719573065, -0.1459327326977227, 0.02375905590688664], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [23.57248690861876, 13.66015912213571, 14.813560884485973, 4.364550220826941, 18.633595220591246, 24.955647643341372]}, "tinfo": {"Term": ["ringgit", "dollar", "u", "million", "local", "close", "said", "food", "currency", "versus", "greenback", "yen", "oil", "euro", "market", "pound", "cent", "traded", "crude", "higher", "per", "innes", "singapore", "note", "british", "rating", "fund", "bernama", "visavis", "major", "helicopter", "emergency", "halal", "sabah", "jakim", "rajan", "food", "father", "college", "rmaf", "unity", "12mp", "hawker", "stall", "ramadan", "ordinance", "russia", "quantity", "fleet", "cocacola", "percent", "ridzwan", "wkb", "collection", "immigrant", "russian", "shakir", "purplebundle", "music", "mohideen", "implementation", "2030", "poverty", "subscription", "mco", "i", "education", "problem", "plan", "country", "relation", "need", "yang", "item", "government", "economic", "people", "covid19", "new", "effort", "time", "back", "pandemic", "still", "national", "health", "also", "one", "malaysia", "economy", "business", "year", "digital", "said", "activity", "consumer", "world", "2020", "vaccine", "well", "development", "would", "2021", "sovereign", "sukuk", "mahb", "turkey", "exporter", "trust", "ytl", "guterres", "bimb", "exposure", "norge", "yeoh", "reit", "30year", "esg", "phone", "mahbs", "refinancing", "downgrade", "bgsef", "attracted", "lira", "passenger", "sen", "affin", "hwang", "replaced", "marriott", "npi", "antonio", "rating", "mobile", "debt", "issuance", "invested", "agency", "passive", "fund", "ban", "index", "bank", "bhd", "financial", "sapura", "malaysia", "investment", "cent", "per", "said", "investor", "management", "asset", "million", "government", "market", "global", "business", "company", "billion", "malaysian", "country", "due", "also", "would", "u", "currency", "year", "new", "rbnz", "inc", "robertson", "msci", "emergingmarket", "adb", "morgan", "peaked", "stanley", "plc", "electric", "duo", "boom", "zainuddin", "gainer", "outperform", "ceo", "orr", "remit", "biotech", "azmin", "400", "count", "posted", "midf", "accommodative", "valued", "shahril", "musk", "allegedly", "emerging", "stock", "stability", "bursa", "bond", "trillion", "rcep", "monetary", "quarter", "inflation", "energy", "external", "bhd", "sapura", "cent", "per", "2020", "investor", "policy", "year", "market", "said", "trade", "bank", "bitcoin", "malaysia", "positive", "january", "would", "company", "could", "billion", "price", "today", "currency", "economy", "government", "china", "global", "economic", "u", "parcel", "educational", "shahrizal", "ihhs", "yorio", "thodex", "campaign", "mra", "marib", "adel", "care", "loh", "hospital", "fy20", "acute", "prof", "reallife", "displaced", "dished", "insecurity", "lahj", "metaverses", "hadramawt", "hygiene", "decentraland", "che", "empty", "zuppinger", "realworld", "lodging", "yemeni", "child", "patient", "victim", "humanitarian", "virtual", "turkish", "estate", "physical", "prosecutor", "site", "conflict", "million", "real", "nearly", "republic", "dr", "land", "hotel", "said", "year", "war", "buy", "investor", "ihh", "earnings", "people", "market", "world", "per", "covid19", "billion", "value", "cent", "like", "pandemic", "2020", "would", "currency", "malaysia", "the", "yen", "innes", "visavis", "axi", "stephen", "japanese", "euro", "versus", "slightly", "9am", "mixed", "british", "ringgit", "greenback", "pound", "crude", "opec", "depreciated", "am", "except", "dealer", "firmer", "thursday", "treasury", "close", "rollout", "luno", "decreased", "myanmar", "cautious", "traded", "dollar" ...

# %%
lda_corpus = ldamodel[doc_term_matrix]

# %%
[doc for doc in lda_corpus]
# Out:
# [[(0, 0.0007475675),
#   (1, 0.99626315),
#   (2, 0.00074864755),
#   (3, 0.000744406),
#   (4, 0.00074714975),
#   (5, 0.00074906345)],
#  [(0, 0.0011866852),
#   (1, 0.0011879489),
#   (2, 0.24497171),
#   (3, 0.0011845786),
#   (4, 0.7502797),
#   (5, 0.001189391)],
#  [(0, 0.00018132912),
#   (1, 0.00018087843),
#   (2, 0.0001809545),
#   (3, 0.00018044717),
#   (4, 0.00018137739),
#   (5, 0.999095)],
#  [(0, 0.00030390965),
#   (1, 0.00030245705),
#   (2, 0.00030232128),
#   (3, 0.00030203417),
#   (4, 0.7084805),
#   (5, 0.29030883)],
#  [(0, 0.0011909495),
#   (1, 0.0011922389),
#   (2, 0.001188349),
#   (3, 0.0011866064),
#   (4, 0.0011869841),
#   (5, 0.99405485)],
#  [(0, 0.00079842476),
#   (1, 0.0007993867),
#   (2, 0.0008016823),
#   (3, 0.00079629617),
#   (4, 0.9960039),
#   (5, 0.0008002611)],
#  [(0, 0.0009468091),
#   (1, 0.00094563374),
#   (2, 0.0009482616),
#   (3, 0.0009446403),
#   (4, 0.0009485378),
#   (5, 0.9952661)],
#  [(0, 0.000629406),
#   (1, 0.3336232),
#   (2, 0.00062977),
#   (3, 0.0006269225),
#   (4, 0.00062984007),
#   (5, 0.66386086)],
#  [(0, 0.000999129),
#   (1, 0.0009982503),
#   (2, 0.42919227),
#   (3, 0.0009955523),
#   (4, 0.5668144),
#   (5, 0.0010003764)],
#  [(0, 0.45009816),
#   (1, 0.0010662678),
#   (2, 0.0010599392),
#   (3, 0.0010524517),
#   (4, 0.5456624),
#   (5, 0.0010607892)],
#  [(0, 0.99821633),
#   (1, 0.0003569505),
#   (2, 0.00035719277),
#   (3, 0.00035593455),
#   (4, 0.00035631566),
#   (5, 0.00035723243)],
#  [(0, 0.001590243),
#   (1, 0.0015908034),
#   (2, 0.00159226),
#   (3, 0.0015896439),
#   (4, 0.9920454),
#   (5, 0.0015916742)],
#  [(0, 0.00034133313),
#   (1, 0.998292),
#   (2, 0.00034219428),
#   (3, 0.00034068196),
#   (4, 0.0003417849),
#   (5, 0.0003420067)],
#  [(0, 0.0007656643),
#   (1, 0.00076705666),
#   (2, 0.00076633884),
#   (3, 0.9961659),
#   (4, 0.00076790294),
#   (5, 0.0007672055)],
#  [(0, 0.99811256),
#   (1, 0.00037703424),
#   (2, 0.00037714577),
#   (3, 0.00037633476),
#   (4, 0.0003792539),
#   (5, 0.00037767776)],
#  [(0, 0.0019407467),
#   (1, 0.0019424858),
#   (2, 0.0019421373),
#   (3, 0.0019397544),
#   (4, 0.9902939),
#   (5, 0.0019409411)],
#  [(0, 0.0011651712),
#   (1, 0.0011640914),
#   (2, 0.0011631557),
#   (3, 0.0011625001),
#   (4, 0.94768715),
#   (5, 0.047657922)],
#  [(0, 0.001100795),
#   (1, 0.0011072279),
#   (2, 0.0011053757),
#   (3, 0.0010999391),
#   (4, 0.99448097),
#   (5, 0.0011057615)],
#  [(0, 0.0011572104),
#   (1, 0.9942038),
#   (2, 0.0011600304),
#   (3, 0.0011539673),
#   (4, 0.0011659731),
#   (5, 0.001159013)],
#  [(0, 0.00040761527),
#   (1, 0.00040829202),
#   (2, 0.00040822243),
#   (3, 0.0004063073),
#   (4, 0.45774764),
#   (5, 0.54062194)],
#  [(0, 0.0007556943),
#   (1, 0.00075648405),
#   (2, 0.0007572961),
#   (3, 0.0007549765),
#   (4, 0.00075709797),
#   (5, 0.99621844)],
#  [(0, 0.00073453895),
#   (1, 0.0007323034),
#   (2, 0.0007336103),
#   (3, 0.0007316073),
#   (4, 0.0007384472),
#   (5, 0.9963295)],
#  [(0, 0.00093112426),
#   (1, 0.99533933),
#   (2, 0.000933517),
#   (3, 0.0009293603),
#   (4, 0.00093310425),
#   (5, 0.000933567)],
#  [(0, 0.00054048304),
#   (1, 0.00053987536),
#   (2, 0.0005408178),
#   (3, 0.0005399695),
#   (4, 0.00054200686),
#   (5, 0.99729687)],
#  [(0, 0.0007685303),
#   (1, 0.996153),
#   (2, 0.0007716943),
#   (3, 0.0007676718),
#   (4, 0.00076897605),
#   (5, 0.0007701264)],
#  [(0, 0.0010029146),
#   (1, 0.0010041241),
#   (2, 0.0010043167),
#   (3, 0.0010017757),
#   (4, 0.99498343),
#   (5, 0.0010034739)],
#  [(0, 0.0004888114),
#   (1, 0.0004900487),
#   (2, 0.7627436),
#   (3, 0.00048829505),
#   (4, 0.23529895),
#   (5, 0.0004902743)],
#  [(0, 0.00067140086),
#   (1, 0.0006695412),
#   (2, 0.00067219295),
#   (3, 0.000669583),
#   (4, 0.00066947116),
#   (5, 0.99664783)],
#  [(0, 0.0010478146),
#   (1, 0.0010461228),
#   (2, 0.0010478086),
#   (3, 0.0010450374),
#   (4, 0.5846519),
#   (5, 0.4111613)],
#  [(0, 0.00034627298),
#   (1, 0.00034578852),
#   (2, 0.00034534122),
#   (3, 0.9982712),
#   (4, 0.0003455159),
#   (5, 0.00034589865)],
#  [(0, 0.0009918611),
#   (1, 0.0009920668),
#   (2, 0.0009918713),
#   (3, 0.0009894222),
#   (4, 0.653108),
#   (5, 0.34292674)],
#  [(0, 0.000579386),
#   (1, 0.997104),
#   (2, 0.00057822897),
#   (3, 0.0005778404),
#   (4, 0.0005815222),
#   (5, 0.00057898165)],
#  [(0, 0.0015231037),
#   (1, 0.0015246752),
#   (2, 0.001527711),
#   (3, 0.0015210098),
#   (4, 0.7178932),
#   (5, 0.27601033)],
#  [(0, 0.00063920993),
#   (1, 0.9967958),
#   (2, 0.0006409255),
#   (3, 0.00063938816),
#   (4, 0.000644813),
#   (5, 0.0006399169)],
#  [(0, 0.00051327515),
#   (1, 0.00051493617),
#   (2, 0.00051380496),
#   (3, 0.00051137694),
#   (4, 0.00051273743),
#   (5, 0.99743384)],
#  [(0, 0.0006039871),
#   (1, 0.00060434977),
#   (2, 0.99698263),
#   (3, 0.0006021776),
#   (4, 0.0006025647),
#   (5, 0.0006043653)],
#  [(0, 0.0005072012),
#   (1, 0.00050674303),
#   (2, 0.0005067383),
#   (3, 0.9974644),
#   (4, 0.0005065781),
#   (5, 0.00050825375)],
#  [(0, 0.0006446534),
#   (1, 0.9967692),
#   (2, 0.0006455577),
#   (3, 0.0006439675),
#   (4, 0.00065107056),
#   (5, 0.0006456256)],
#  [(0, 0.0011209408),
#   (1, 0.0011228862),
#   (2, 0.0011250254),
#   (3, 0.0011215227),
#   (4, 0.99438715),
#   (5, 0.0011225166)],
#  [(0, 0.000611027),
#   (1, 0.99694073),
#   (2, 0.00061338954),
#   (3, 0.00061098393),
#   (4, 0.0006111691),
#   (5, 0.00061272003)],
#  [(0, 0.0010961174),
#   (1, 0.0010963993),
#   (2, 0.9945148),
#   (3, 0.001094414),
#   (4, 0.0010959777),
#   (5, 0.0011022472)],
#  [(0, 0.9976107),
#   (1, 0.00047779412),
#   (2, 0.00047789598),
#   (3, 0.00047695218),
#   (4, 0.00047807198),
#   (5, 0.0004785899)],
#  [(0, 0.00089473906),
#   (1, 0.0008969743),
#   (2, 0.00089828315),
#   (3, 0.0008937175),
#   (4, 0.9955189),
#   (5, 0.00089731807)],
#  [(0, 0.0011699384),
#   (1, 0.0011719868),
#   (2, 0.0011753552),
#   (3, 0.0011678118),
#   (4, 0.9941435),
#   (5, 0.0011714181)],
#  [(0, 0.0015467484),
#   (1, 0.0015474075),
#   (2, 0.0015492057),
#   (3, 0.0015460971),
#   (4, 0.9922631),
#   (5, 0.0015475117)],
#  [(0, 0.99971884),
#   (1, 5.6244226e-05),
#   (2, 5.6265613e-05),
#   (3, 5.607443e-05),
#   (4, 5.6260986e-05),
#   (5, 5.63355e-05)],
#  [(0, 0.001014641),
#   (1, 0.0010159708),
#   (2, 0.0010144443),
#   (3, 0.0010139664),
#   (4, 0.99492514),
#   (5, 0.0010158849)],
#  [(0, 0.00043191024),
#   (1, 0.00043423203),
#   (2, 0.00043388642),
#   (3, 0.0004316636),
#   (4, 0.00043296494),
#   (5, 0.99783534)],
#  [(0, 0.0006058992),
#   (1, 0.00060706213),
#   (2, 0.00060834124),
#   (3, 0.99696493),
#   (4, 0.0006065867),
#   (5, 0.0006071799)],
#  [(0, 0.00036481675),
#   (1, 0.00036478692),
#   (2, 0.9981769),
#   (3, 0.00036336188),
#   (4, 0.0003649802),
#   (5, 0.00036514498)],
#  [(0, 0.0014657843),
#   (1, 0.0014675716),
#   (2, 0.0014673122),
#   (3, 0.001464775),
#   (4, 0.9926673),
#   (5, 0.0014672165)],
#  [(0, 0.0024909624),
#   (1, 0.0024919978),
#   (2, 0.0024928928),
#   (3, 0.0024955233),
#   (4, 0.98753613),
#   (5, 0.002492505)],
#  [(0, 0.9975374),
#   (1, 0.0004916294),
#   (2, 0.00049257796),
#   (3, 0.00049205276),
#   (4, 0.00049324584),
#   (5, 0.0004931248)],
#  [(0, 0.0005483128),
#   (1, 0.0005471319),
#   (2, 0.00054689735),
#   (3, 0.0005476926),
#   (4, 0.0005471427),
#   (5, 0.99726284)],
#  [(0, 0.00094982603),
#   (1, 0.0009513918),
#   (2, 0.85479933),
#   (3, 0.14140348),
#   (4, 0.00094556337),
#   (5, 0.0009504434)],
#  [(0, 0.00082621543),
#   (1, 0.00082575285),
#   (2, 0.9958636),
#   (3, 0.0008246403),
#   (4, 0.0008284882),
#   (5, 0.0008313398)],
#  [(0, 0.002497331),
#   (1, 0.0024957298),
#   (2, 0.0024957291),
#   (3, 0.0024934825),
#   (4, 0.98751867),
#   (5, 0.002499106)],
#  [(0, 0.122162506),
#   (1, 0.0010950662),
#   (2, 0.001093154),
#   (3, 0.0010914999),
#   (4, 0.5724673),
#   (5, 0.30209044)],
#  [(0, 0.0008961017),
#   (1, 0.0008954919),
#   (2, 0.40672097),
#   (3, 0.00089610193),
#   (4, 0.58969283),
#   (5, 0.00089849235)],
#  [(0, 0.00047977013),
#   (1, 0.00048073774),
#   (2, 0.9975974),
#   (3, 0.00047867664),
#   (4, 0.0004830364),
#   (5, 0.00048041312)],
#  [(0, 0.0012125793),
#   (1, 0.001213383),
#   (2, 0.0012164111),
#   (3, 0.0012110185),
#   (4, 0.9939328),
#   (5, 0.0012138106)],
#  [(0, 0.0013537178),
#   (1, 0.22068474),
#   (2, 0.0013554202),
#   (3, 0.001349227),
#   (4, 0.7739015),
#   (5, 0.0013553341)],
#  [(0, 0.00097366335),
#   (1, 0.000973906),
#   (2, 0.99513155),
#   (3, 0.0009738123),
#   (4, 0.0009716139),
#   (5, 0.0009754949)],
#  [(0, 0.0008347549),
#   (1, 0.00083457597),
#   (2, 0.99582094),
#   (3, 0.00083250797),
#   (4, 0.0008386588),
#   (5, 0.00083858205)],
#  [(0, 0.9993459),
#   (1, 0.00013085223),
#   (2, 0.00013079088),
#   (3, 0.00013067154),
#   (4, 0.00013071351),
#   (5, 0.00013102831)],
#  [(0, 0.0004397295),
#   (1, 0.00044049087),
#   (2, 0.9978011),
#   (3, 0.00043830968),
#   (4, 0.00044029605),
#   (5, 0.0004400933)],
#  [(0, 0.61463493),
#   (1, 0.0010673593),
#   (2, 0.001067112),
#   (3, 0.0010602024),
#   (4, 0.15275577),
#   (5, 0.22941461)],
#  [(0, 0.002648535),
#   (1, 0.0026494453),
#   (2, 0.002649615),
#   (3, 0.0026475657),
#   (4, 0.9867556),
#   (5, 0.002649211)],
#  [(0, 0.002783524),
#   (1, 0.15411057),
#   (2, 0.0027872352),
#   (3, 0.0027831027),
#   (4, 0.83474946),
#   (5, 0.0027861441)],
#  [(0, 0.0029261187),
#   (1, 0.0029277757),
#   (2, 0.002928958),
#   (3, 0.002926451),
#   (4, 0.9853631),
#   (5, 0.002927568)],
#  [(0, 0.99591196),
#   (1, 0.00081607426),
#   (2, 0.00081706647),
#   (3, 0.0008165962),
#   (4, 0.00082029117),
#   (5, 0.0008179736)],
#  [(0, 0.0012733055),
#   (1, 0.0012698356),
#   (2, 0.46480262),
#   (3, 0.0012699598),
#   (4, 0.53011173),
#   (5, 0.0012725238)],
#  [(0, 0.99699056),
#   (1, 0.00060135074),
#   (2, 0.00060181454),
#   (3, 0.0006009862),
#   (4, 0.00060228707),
#   (5, 0.0006029618)],
#  [(0, 0.0011263133),
#   (1, 0.001123824),
#   (2, 0.0011275788),
#   (3, 0.0011218552),
#   (4, 0.99437356),
#   (5, 0.0011268992)],
#  [(0, 0.0027341407),
#   (1, 0.0027353938),
#   (2, 0.0027364984),
#   (3, 0.0027348702),
#   (4, 0.9863226),
#   (5, 0.0027365517)],
#  [(0, 0.0009747231),
#   (1, 0.00097641675),
#   (2, 0.0009782193),
#   (3, 0.0009719416),
#   (4, 0.9951235),
#   (5, 0.00097518635)],
#  [(0, 0.00090005447),
#   (1, 0.0009020606),
#   (2, 0.0009045236),
#   (3, 0.0008992497),
#   (4, 0.1717771),
#   (5, 0.82461697)],
#  [(0, 0.0033370024),
#   (1, 0.0033369076),
#   (2, 0.0033377185),
#   (3, 0.0033357423),
#   (4, 0.9833149),
#   (5, 0.0033378021)],
#  [(0, 0.00085855357),
#   (1, 0.0008606844),
#   (2, 0.0008599838),
#   (3, 0.000858392),
#   (4, 0.0008608964),
#   (5, 0.9957015)],
#  [(0, 0.996114),
#   (1, 0.000777849),
#   (2, 0.00077768654),
#   (3, 0.00077496516),
#   (4, 0.00077637937),
#   (5, 0.000779105)],
#  [(0, 0.0003366132),
#   (1, 0.00033673196),
#   (2, 0.9983165),
#   (3, 0.0003360253),
#   (4, 0.0003369252),
#   (5, 0.00033717108)],
#  [(0, 0.996617),
#   (1, 0.0006774121),
#   (2, 0.000676451),
#   (3, 0.0006738674),
#   (4, 0.0006769799),
#   (5, 0.0006782728)],
#  [(0, 0.0021131963),
#   (1, 0.0021144217),
#   (2, 0.0021158503),
#   (3, 0.002111922),
#   (4, 0.98943),
#   (5, 0.0021145658)],
#  [(0, 0.00068269565),
#   (1, 0.0006837088),
#   (2, 0.00068415166),
#   (3, 0.00068031164),
#   (4, 0.07378108),
#   (5, 0.923488)],
#  [(0, 0.00020680271),
#   (1, 0.99896777),
#   (2, 0.00020656172),
#   (3, 0.00020572548),
#   (4, 0.00020627878),
#   (5, 0.00020691463)],
#  [(0, 0.001031584),
#   (1, 0.0010315983),
#   (2, 0.0010292359),
#   (3, 0.0010253957),
#   (4, 0.9948489),
#   (5, 0.0010332634)],
#  [(0, 0.00032637702),
#   (1, 0.00032590257),
#   (2, 0.00032609786),
#   (3, 0.0003254779),
#   (4, 0.00032600298),
#   (5, 0.9983701)],
#  [(0, 0.0006069077),
#   (1, 0.00060811685),
#   (2, 0.00060852926),
#   (3, 0.00060658145),
#   (4, 0.00061045855),
#   (5, 0.9969594)],
#  [(0, 0.0003471945),
#   (1, 0.00034650922),
#   (2, 0.00034759275),
#   (3, 0.00034517658),
#   (4, 0.07412504),
#   (5, 0.9244885)],
#  [(0, 0.00088631106),
#   (1, 0.00088541856),
#   (2, 0.00088691385),
#   (3, 0.00088355015),
#   (4, 0.9955712),
#   (5, 0.00088658015)],
#  [(0, 0.0005745208),
#   (1, 0.0005744749),
#   (2, 0.00057420286),
#   (3, 0.0005715423),
#   (4, 0.0005733636),
#   (5, 0.99713194)],
#  [(0, 0.00062165165),
#   (1, 0.9968864),
#   (2, 0.0006235129),
#   (3, 0.00062265916),
#   (4, 0.0006226748),
#   (5, 0.0006230936)],
#  [(0, 0.00034760067),
#   (1, 0.00034690535),
#   (2, 0.99826443),
#   (3, 0.00034545554),
#   (4, 0.00034777707),
#   (5, 0.0003478216)],
#  [(0, 0.00051867875),
#   (1, 0.00052047224),
#   (2, 0.9974037),
#   (3, 0.00051738904),
#   (4, 0.00052044296),
#   (5, 0.0005193203)],
#  [(0, 0.0011169113),
#   (1, 0.0011176121),
#   (2, 0.0011206821),
#   (3, 0.0011143427),
#   (4, 0.9944121),
#   (5, 0.0011183359)],
#  [(0, 0.0012886334),
#   (1, 0.0012877724),
#   (2, 0.0012882296),
#   (3, 0.0012868964),
#   (4, 0.99356014),
#   (5, 0.0012883417)],
#  [(0, 0.0006178569),
#   (1, 0.9969218),
#   (2, 0.0006141831),
#   (3, 0.0006151575),
#   (4, 0.0006152675),
#   (5, 0.0006157209)],
#  [(0, 0.00058146415),
#   (1, 0.00058094505),
#   (2, 0.0005809995),
#   (3, 0.00057975686),
#   (4, 0.99709505),
#   (5, 0.00058185426)],
#  [(0, 0.0015474384),
#   (1, 0.0015477588),
#   (2, 0.27782485),
#   (3, 0.0015476169),
#   (4, 0.7159832),
#   (5, 0.0015491431)],
#  [(0, 0.0014320477),
#   (1, 0.99683225),
#   (2, 0.00043350772),
#   (3, 0.0004332495),
#   (4, 0.0004331262),
#   (5, 0.00043582963)],
#  [(0, 0.0014535289),
#   (1, 0.0014547976),
#   (2, 0.0014565011),
#   (3, 0.0014514405),
#   (4, 0.99272794),
#   (5, 0.0014557755)],
#  [(0, 0.0015511466),
#   (1, 0.0015499649),
#   (2, 0.0015543036),
#   (3, 0.0015461625),
#   (4, 0.99224293),
#   (5, 0.0015555207)],
#  [(0, 0.0006488175),
#   (1, 0.00064865395),
#   (2, 0.84301263),
#   (3, 0.00064622954),
#   (4, 0.15439402),
#   (5, 0.00064966176)],
#  [(0, 0.0017065855),
#   (1, 0.0017079212),
#   (2, 0.36104763),
#   (3, 0.0017032386),
#   (4, 0.63212526),
#   (5, 0.0017093477)],
#  [(0, 0.4154853),
#   (1, 0.01943806),
#   (2, 0.00026119844),
#   (3, 0.00026000277),
#   (4, 0.1144226),
#   (5, 0.45013282)],
#  [(0, 0.00013566055),
#   (1, 0.00013540458),
#   (2, 0.00013529317),
#   (3, 0.00013495443),
#   (4, 0.00013512885),
#   (5, 0.99932355)],
#  [(0, 0.0010483199),
#   (1, 0.001051093),
#   (2, 0.8611261),
#   (3, 0.0010455141),
#   (4, 0.13467671),
#   (5, 0.0010522166)]]

# %%
scores = list(chain(*[[score for topic_id,score in topic] \
                      for topic in [doc for doc in lda_corpus]]))

threshold = sum(scores)/len(scores)
print(threshold)
# Out:
# 0.16666666732157084

# %%
cluster1 = [j for i,j in zip(lda_corpus,df.index) if i[0][1] > threshold]
cluster1 = [j for i,j in zip(lda_corpus,df.index) if i[0][1] > threshold]
cluster1 = [j for i,j in zip(lda_corpus,df.index) if i[0][1] > threshold]
cluster1 = [j for i,j in zip(lda_corpus,df.index) if i[0][1] > threshold]
cluster1 = [j for i,j in zip(lda_corpus,df.index) if i[0][1] > threshold]
